# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv(r'..\..\data\raw\awi_spam_emails.csv')
df2 = pd.read_csv(r'..\..\data\raw\email_spam.csv')
df3 = pd.read_csv(r'..\..\data\raw\fq_spam.csv')
df4 = pd.read_csv(r'..\..\data\raw\spam_or_not_spam.csv')
df5 = pd.read_csv(r'..\..\data\raw\uciml_spam.csv', encoding='latin')
df6 = pd.read_csv(r'..\..\data\raw\vg_email.csv')
df7 = pd.read_csv(r'..\..\data\raw\ps_spam.csv')
df8 = pd.read_csv(r'..\..\data\raw\ay_spam.csv')
df9 = pd.read_csv(r'..\..\data\raw\lingSpam.csv')
df10 = pd.read_csv(r'..\..\data\raw\completeSpamAssassin.csv')
df11 = pd.read_csv(r'..\..\data\raw\enronSpamSubset.csv')
df12 = pd.read_csv(r'..\..\data\raw\underscore_email.csv')
df13 = pd.read_csv(r'..\..\data\raw\SMSSpamCollection.csv')

# %%
list_of_df = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13]
for ds in list_of_df:
    display(ds.describe(include='all'))
# Out:
#        Category                 Message
# count      5572                    5572
# unique        2                    5157
# top         ham  Sorry, I'll call later
# freq       4825                      30
#        Category                 Message
# count      5573                    5573
# unique        3                    5158
# top         ham  Sorry, I'll call later
# freq       4825                      30
#        Category                 Message
# count      5572                    5572
# unique        2                    5157
# top         ham  Sorry, I'll call later
# freq       4825                      30
#                                  email        label
# count                             2999  3000.000000
# unique                            2872          NaN
# top     url URL date not supplied URL           NaN
# freq                                10          NaN
# mean                               NaN     0.166667
# ...

# %% [markdown]
# the datasets 1,2 and 3 appear to be similar

# %% [markdown]
# ### Standarizing the dataset

# %%
for ds in list_of_df:
    ds.columns = ds.columns.str.lower().str.replace(' ', '_')

# %%
for num,ds in enumerate(list_of_df):
    print(num, ds.columns)
# Out:
# 0 Index(['category', 'message'], dtype='object')
# 1 Index(['category', 'message'], dtype='object')
# 2 Index(['category', 'message'], dtype='object')
# 3 Index(['email', 'label'], dtype='object')
# 4 Index(['v1', 'v2', 'unnamed:_2', 'unnamed:_3', 'unnamed:_4'], dtype='object')
# 5 Index(['unnamed:_0', 'label', 'text', 'label_num'], dtype='object')
# 6 Index(['email', 'label'], dtype='object')
# 7 Index(['category', 'message'], dtype='object')
# 8 Index(['unnamed:_0', 'body', 'label'], dtype='object')
# 9 Index(['unnamed:_0', 'body', 'label'], dtype='object')
# 10 Index(['unnamed:_0.1', 'unnamed:_0', 'body', 'label'], dtype='object')
# 11 Index(['text', 'spam'], dtype='object')
# 12 Index(['category', 'message', 'unnamed:_2', 'unnamed:_3', 'unnamed:_4',
#        'unnamed:_5', 'unnamed:_6', 'unnamed:_7', 'unnamed:_8'],
#       dtype='object')

# %%
# standardizing all the datasets
df4 = df4[['label','email']].rename(columns={'label':'category','email':'message'})
df5 = df5[['v1','v2']].rename(columns={'v1':'category','v2':'message'})
df6 = df6[['label_num','text']].rename(columns={'label_num':'category','text':'message'})
df7 = df7[['label','email']].rename(columns={'label':'category','email':'message'})
df9 = df9[['label','body']].rename(columns={'label':'category','body':'message'})
df10 = df10[['label','body']].rename(columns={'label':'category','body':'message'})
df11 = df11[['label','body']].rename(columns={'label':'category','body':'message'})
df12 = df12[['spam','text']].rename(columns={'spam':'category','text':'message'})
df13 = df13[['category','message']]

# %%
list_of_df = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13]

# %%
for ds in list_of_df:
    print(ds.columns)
# Out:
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')
# Index(['category', 'message'], dtype='object')

# %%
# appending all the datasets into one
df = pd.concat(list_of_df)
df.shape
# Out:
# (66165, 2)

# %%
# dropping all the identical rows of data
df = df.drop_duplicates()
df.shape
# Out:
# (42220, 2)

# %%
# checking the classes
df['category'].value_counts()
# Out:
# category
# 0                 21313
# 1                  9819
# ham                9504
# spam               1583
# {"mode":"full"        1
# Name: count, dtype: int64

# %%
df = df.loc[~df['category'].astype(str).str.contains(r'{"mode":"full"', regex=True)]
df['category'] = df['category'].replace({'ham': 0, 'spam': 1})
# Out:
# C:\Users\Asif Sayyed\AppData\Local\Temp\ipykernel_18696\1361099758.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['category'] = df['category'].replace({'ham': 0, 'spam': 1})

# %%
df['category'].value_counts(normalize=True)
# Out:
# category
# 0    0.729932
# 1    0.270068
# Name: proportion, dtype: float64

# %%
df.to_csv(r'..\..\data\processed\spam_dataset.csv', index=False)

# %% [markdown]
# [Next notebook](https://github.com/Asifdotexe/SpamDetection/blob/main/code/notebooks/issue-3-as-data-preprocessing.ipynb)
